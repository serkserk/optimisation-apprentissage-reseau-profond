# %%
from tensorflow.examples.tutorials.mnist import input_data
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd

# %matplotlib inline

#plt.style.use('seaborn')

#plt.style.available

# %% [markdown]
# # Présentation du jeu de Données MNIST

# %% [markdown]
# Le jeu de données MNIST regroupe 65 000 images de chiffres de 0 à 9 écrits à la main répartis dans 2 dataset, le premier (train) comporte 55 000 images et le second (test) en comporte 10 000. Ces images sont de dimensions 28x28 donc composés de 784 pixels chacunes et sont labélisé. Les classes sont répartis de façon relativement équilibrés.

# %% [markdown]
# ## Extraction du jeu de données

# %%
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)

labels_train = np.dot(mnist.train.labels,np.array(range(10)))
labels_test = np.dot(mnist.train.labels,np.array(range(10)))
# Out:
# WARNING:tensorflow:From <ipython-input-2-d9dd44570f2e>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From c:\users\serks\appdata\local\programs\python\python36\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From c:\users\serks\appdata\local\programs\python\python36\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %% [markdown]
# ### LABELS REPARTION

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1,2,1)

plt.hist(labels_train,width = 0.8)
plt.title("Répartition des classes dans train")
plt.ylabel("nombre")
plt.xlabel("classe")

plt.subplot(1,2,2)

plt.hist(labels_test,width = 0.8)
plt.title("Répartition des classes dans test")
plt.ylabel("nombre")
plt.xlabel("classe")

plt.show()

# %%
images = mnist.train.images

# %%
plt.figure(figsize= (10,10))

for i in range(9):
    
    plt.subplot(3,3,1+i)
    img = images[i].reshape([28,28])
    plt.imshow(img,cmap = "gray")
    
    
plt.show()
